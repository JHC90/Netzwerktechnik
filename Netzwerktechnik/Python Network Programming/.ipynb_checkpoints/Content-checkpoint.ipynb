# %% [markdown]
# <a href="https://github.com/JHC90/ProgrammierenTrainieren">Basic-Programming-Concepts</a> die ich selbst ausgearbeitet habe

# %% [markdown]
# <h1>Sockets, IPv4, and Simple Client/Server Programming</h1>
# <p>Dieses Kapitel dient der ersten Berührung mit der Sprache und dem erlernen von ausgaben</p>
# <p>Wenn man bereits eine Programmiersprache beherrscht kann hier schnell drüber gehoppt werden</p>
#
# <table>
#   <tr>
#     <th>Python-Lösung</th>
#     <th>Aufgabe</th>
#     <th>Beschreibung</th>
#   </tr>
#
# <tr>
#   <td><a href="./Chapter1/Chapter1_0-Basic.ipynb">Task 0</a></td>
#      <td>Basis-Terminologie für das Verständnis der Aufgaben</td>
#     <td>
#         <ul>
#         </ul>
#      </td>
#    </tr>
#
#  <tr>
#      <td><a href="./Chapter1/Chapter1_1.ipynb">Task 1</a></td>
#      <td>Printing your machine's name and IPv4 address</td>
#     <td>
#         <ul>
#             <li>
#                 Abrufen des Hostnamen der lokalen Maschine
#             </li>
#             <li>
#                 Abrufen der IP-Adresse der lokalen Maschine
#             </li>
#             <li>
#                 Erklärung Socket
#             </li>
#         </ul>
#      </td>
#    </tr>
#
#    <tr>
#      <td><a href="./Chapter1/Chapter1_2.ipynb">Task 2</a></td>
#      <td>Retrieving a remote machine's IP address</td>
#      <td>
#          <ul>
#             <li>
#                 Abrufen des Hostnamen der remote Maschine
#             </li>
#             <li>
#                 Abrufen der IP-Adresse der remote Maschine
#             </li>
#             <li>
#                 Abfrage von sowohl lokalen als auch intenrnet Maschinen
#             </li>
#         </ul>
#     </td>
#    </tr>
#
#    <tr>
#      <td><a href="./Chapter1/Chapter1_3.ipynb">Task 3</a></td>
#      <td>Converting an IPv4 address to different formats</td>
#      <td>
#          <ul>
#             <li>
#                 Konvertieren von IP-Adressen aus der Dezimalschreibweise (unpacked) in packed
#             </li>
#         </ul>
#     </td>
#    </tr>
#
#    <tr>
#      <td><a href="./Chapter1/Chapter1_4.ipynb">Task 4</a></td>
#      <td>Finding a service name, given the port and protocol</td>
#      <td>
#          <ul>
#             <li>
#                 Finde einen Service zu einem gegebenem Port
#             </li>
#         </ul>
#     </td>
#    </tr>
#
#    <tr>
#      <td><a href="./Chapter1/Chapter1_5.ipynb">Task 5</a></td>
#      <td>Converting integers to and from host to network byte order</td>
#      <td>
#          <ul>
#             <li>
#                 rechne Zahl in Longbyte = host oder shortbyte = netzwerk um
#             </li>
#         </ul>
#     </td>
#    </tr>
#
#
#    <tr>
#      <td><a href="./Chapter1/Chapter1_6.ipynb">Task 6</a></td>
#      <td>Setting and getting the default socket timeout</td>
#      <td>
#          <ul>
#             <li>
#                 Konfiugirere die Socket time
#             </li>
#         </ul>
#     </td>
#    </tr>
#
#
#    <tr>
#      <td><a href="./Chapter1/Chapter1_7.ipynb">Task 7</a></td>
#      <td>Handling socket errors gracefully</td>
#      <td>
#          <ul>
#             <li>
#                 Aufrufen einer bestimmten Applikation definiert durch Host = Domain & port & file
#             </li>
#             <li>
#                 Abfangen der dabei potentiell möglichen Fehler druch Try & Excepts
#             </li>
#         </ul>
#     </td>
#    </tr>
#
#    <tr>
#      <td><a href="./Chapter1/Chapter1_8.ipynb">Task 8</a></td>
#      <td>Modifying a socket's send/receive buffer sizes</td>
#      <td>
#          <ul>
#             <li>
#                 Ändern der Socketgröße
#             </li>
#         </ul>
#     </td>
#    </tr>
#
#    <tr>
#      <td><a href="./Chapter1/Chapter1_9.ipynb">Task 9</a></td>
#      <td>Changing a socket to the blocking/nonblocking mode</td>
#      <td>
#          <ul>
#             <li>
#                 Ändern der Socketgröße
#             </li>
#         </ul>
#     </td>
#    </tr>
#
#    <tr>
#      <td><a href="./Chapter1/Chapter1_10.ipynb">Task 10</a></td>
#      <td>Reusing socket addresses</td>
#      <td>
#          <ul>
#               <li>
#                 !!! noch nicht bearbeitet, da ich gegenwärtig dafür keinen Einsatz habe
#             </li>
#             <li>
#                 Einem Socket immer die gleiche Adresse zuweisen // bspw server der immer auf die gleiche Adresse lauschen soll
#             </li>
#         </ul>
#     </td>
#    </tr>
#     <tr>
#      <td><a href="./Chapter1/Chapter1_11.ipynb">Task 11</a></td>
#      <td>Printing the current time from the internet time server</td>
#      <td>
#          <ul>
#             <li>
#                Gegenwärtige Zeit ausgeben
#             </li>
#         </ul>
#     </td>
#    </tr>
# </table>
