# %%
# Building own Port-scanner 
# you can use this for automated attacks, depending on the port

# %%
from IPython.display import YouTubeVideo

def display_yotube_video(url, **kwargs):
    """
    Displays a Youtube video in a Jupyter notebook.
    
    Args:
        url (string): a link to a Youtube video.
        **kwargs: further arguments for IPython.display.YouTubeVideo
    
    Returns:
        YouTubeVideo: a video that is displayed in your notebook.
    """
    id_ = url.split("=")[-1]
    return YouTubeVideo(id_, **kwargs)

display_yotube_video("https://www.youtube.com/watch?v=h30pCvtCMMQ", width=800, height=600)

# %%
# nmap isntall https://nmap.org/download.html#windows
# pip install python nmap

import nmap

# %%
nm = nmap.PortScanner()
nm.scan("192.168.178.10","22-1000") # Fritzbox2 # will return Json-Format
# Out:
# {'nmap': {'command_line': 'nmap -oX - -p 22-1000 -sV 192.168.178.10',
#   'scaninfo': {'tcp': {'method': 'syn', 'services': '22-1000'}},
#   'scanstats': {'timestr': 'Mon Nov 04 09:05:43 2019',
#    'elapsed': '15.66',
#    'uphosts': '1',
#    'downhosts': '0',
#    'totalhosts': '1'}},
#  'scan': {'192.168.178.10': {'hostnames': [{'name': 'FB7270-Buero.fritz.box',
#      'type': 'PTR'}],
#    'addresses': {'ipv4': '192.168.178.10', 'mac': '00:24:FE:1B:D7:0D'},
#    'vendor': {'00:24:FE:1B:D7:0D': 'AVM GmbH'},
#    'status': {'state': 'up', 'reason': 'arp-response'},
#    'tcp': {53: {'state': 'open',
#      'reason': 'syn-ack',
#      'name': 'domain',
#      'product': '',
#      'version': '',
#      'extrainfo': 'generic dns response: NOTIMP',
#      'conf': '10',
#      'cpe': ''},
#     80: {'state': 'open',
#      'reason': 'syn-ack',
#      'name': 'http',
#      'product': 'FRITZ!Box http config',
#      'version': '',
#      'extrainfo': '',
#      'conf': '10',
# ...

# %%
# each ip must be scaned indiviually
print(nm["192.168.178.10"].hostname())
# Out:
# FB7270-Buero.fritz.box
